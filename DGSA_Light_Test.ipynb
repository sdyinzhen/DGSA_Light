# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#DGSA-light-python" data-toc-modified-id="DGSA-light-python-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>DGSA light python</a></span></li></ul></div>

# %% [markdown]
# # DGSA light python

# %%
import numpy as np
from DGSA_light import DGSA_light
from gsa_pareto_plt import gsa_pareto_plt
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

# %%
parameters = np.load('test_data/m_parameters.npy')
responses = np.load('test_data/m_responses.npy')

# %%
dgsa_measures = DGSA_light(parameters, responses)
gsa_pareto_plt(dgsa_measures)
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 3000/3000 [00:17<00:00, 171.68it/s]
